# %% [markdown]
# # Sales Analysis.
# ## Importing relevant packages.

# %%
import pandas as pd 
import os

# %% [markdown]
# ## Task_1: Merging 12 months of sales data into a single file.

# %%
dataframe = pd.read_csv("./Sales_Data/Sales_April_2019.csv")
filenames = [file for file in os.listdir('./Sales_Data/')]
all_months_data = pd.DataFrame()

for file in filenames:
    dataframe = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data, dataframe])
    
all_months_data.to_csv('all_data.csv',index=False)

# %% [markdown]
# ## reading in updated dataframe.

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head(50)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    209921        USB-C Charging Cable                1      11.95
# 1    209922          Macbook Pro Laptop                1     1700.0
# 2    209923             ThinkPad Laptop                1     999.99
# 3    209924            27in FHD Monitor                1     149.99
# 4    209925  Bose SoundSport Headphones                1      99.99
# 5    209926    Apple Airpods Headphones                1      150.0
# 6    209927    Lightning Charging Cable                1      14.95
# 7    209928    Apple Airpods Headphones                1      150.0
# 8    209929            Wired Headphones                1      11.99
# 9    209930            27in FHD Monitor                1     149.99
# 10   209931    Apple Airpods Headphones                1      150.0
# 11   209932               Flatscreen TV                1      300.0
# 12   209933       AA Batteries (4-pack)                1       3.84
# 13   209934      AAA Batteries (4-pack)                1       2.99
# 14   209935      AAA Batteries (4-pack)                1       2.99
# 15   209936      34in Ultrawide Monitor                1     379.99
# 16   209937       AA Batteries (4-pack)                1       3.84
# 17   209938                      iPhone                1      700.0
# 18   209938            Wired Headphones                1      11.99
# 19   209939                Google Phone                1      600.0
# 20   209940      34in Ultrawide Monitor                1     379.99
# 21   209941            Wired Headphones                1      11.99
# 22   209942      27in 4K Gaming Monitor                1     389.99
# 23   209943      AAA Batteries (4-pack)                3       2.99
# 24   209944            27in FHD Monitor                1     149.99
# 25   209945       AA Batteries (4-pack)                1       3.84
# 26   209946                Google Phone                1      600.0
# 27   209947    Apple Airpods Headphones                1      150.0
# 28   209948          Macbook Pro Laptop                1     1700.0
# 29   209949                Google Phone                1      600.0
# 30   209949        USB-C Charging Cable                1      11.95
# 31   209950            Wired Headphones                2      11.99
# 32   209951      27in 4K Gaming Monitor                1     389.99
# 33   209952                20in Monitor                1     109.99
# 34   209953                Google Phone                1      600.0
# 35   209954                      iPhone                1      700.0
# 36   209955       AA Batteries (4-pack)                1       3.84
# 37   209956       AA Batteries (4-pack)                2       3.84
# 38   209957       AA Batteries (4-pack)                1       3.84
# 39   209958            Wired Headphones                1      11.99
# 40   209959        USB-C Charging Cable                1      11.95
# 41   209960        USB-C Charging Cable                1      11.95
# 42   209960       AA Batteries (4-pack)                1       3.84
# 43   209961                      iPhone                1      700.0
# 44   209961    Lightning Charging Cable                1      14.95
# 45   209962        USB-C Charging Cable                1      11.95
# 46   209963    Lightning Charging Cable                1      14.95
# 47   209964        USB-C Charging Cable                2      11.95
# 48   209965                20in Monitor                1     109.99
# 49   209966    Lightning Charging Cable                1      14.95
#
# 46  06/13/19 18:58             551 Hill St, Boston, MA 02215
# 47  06/11/19 14:30         822 8th St, Los Angeles, CA 90001
# 48  06/24/19 14:00     910 North St, San Francisco, CA 94016
# 49  06/20/19 09:46     743 Adams St, New York City, NY 10001

# %% [markdown]
# ## Cleaning up the Data

# %%
nan_df = all_data[all_data.isnull().any(axis=1)]
nan_df.head()

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'],downcast='float')

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016

# %% [markdown]
# ## Augmented data with additional columns
# ### Task_2: Add Month Column.

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address  Month
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101      6
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016      6
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001      6
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101      6
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016      6

# %% [markdown]
# ### Task_3: Add a Sales Column.

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']

# %% [markdown]
# ## Identify the month with the most sales  and by how much.

# %%
 results = all_data.groupby('Month').sum()
 results
# Out:
#        Quantity Ordered   Price Each       Sales
# Month
# 1                 10903  1811768.375  1822256.75
# 2                 13449  2188884.750  2202022.50
# 3                 17005  2791207.750  2807100.25
# 4                 20558  3367671.000  3390670.25
# 5                 18667  3135125.000  3152606.75
# 6                 15253  2562025.500  2577802.25
# 7                 16072  2632539.500  2647775.75
# 8                 13448  2230345.500  2244467.75
# 9                 13109  2084992.125  2097560.00
# 10                22703  3715554.750  3736726.75
# 11                19798  3180600.750  3199603.25
# 12                28114  4588415.500  4613443.50

# %% [markdown]
# ### Visualizing the Data in a graph.

# %%
import matplotlib.pyplot as plt
 
months = range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.xlabel('Month number')
plt.ylabel('Sales in USD($)')
plt.show()

# %% [markdown]
# ## Identifying the city with the Highest Sales.

# %% [markdown]
# ### Task_4: Creating the City column and extracting the city name from the Purchases Address.

# %%
def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: get_city(x) + ' ' + get_state(x))
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered   Price Each  \
# 0   209921        USB-C Charging Cable                 1    11.950000
# 1   209922          Macbook Pro Laptop                 1  1700.000000
# 2   209923             ThinkPad Laptop                 1   999.989990
# 3   209924            27in FHD Monitor                 1   149.990005
# 4   209925  Bose SoundSport Headphones                 1    99.989998
#
#        Order Date                       Purchase Address  Month        Sales  \
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101      6    11.950000
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016      6  1700.000000
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001      6   999.989990
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101      6   149.990005
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016      6    99.989998
#
#                 City
# 0        Portland ME
# 1   San Francisco CA
# 2     Los Angeles CA
# 3         Seattle WA
# 4   San Francisco CA

# %%
results = all_data.groupby('City').sum()
results
# Out:
#                    Quantity Ordered   Price Each   Month         Sales
# City
#  Atlanta GA                   16602  2779908.250  104794  2.795498e+06
#  Austin TX                    11153  1809873.625   69829  1.819582e+06
#  Boston MA                    22528  3637409.750  141112  3.661642e+06
#  Dallas TX                    16730  2752627.750  104620  2.767976e+06
#  Los Angeles CA               33289  5421435.000  208325  5.452571e+06
#  New York City NY             27932  4635371.000  175741  4.664318e+06
#  Portland ME                   2750   447189.250   17144  4.497583e+05
#  Portland OR                  11303  1860558.250   70621  1.870732e+06
#  San Francisco CA             50239  8211461.500  315520  8.262204e+06
#  Seattle WA                   16553  2733296.000  104941  2.747756e+06

# %%
import matplotlib.pyplot as plt
 
cities = [city for city,df in all_data.groupby('City')]
plt.bar(cities,results['Sales'])
plt.xticks(cities,rotation='vertical',size=8)
plt.xlabel('City name')
plt.ylabel('Sales in USD($)')
plt.show()
